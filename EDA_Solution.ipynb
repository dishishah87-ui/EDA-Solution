# %% [markdown]
# **LIBRARIES**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **READ FILE**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/goodreads.xlsx")

# %% [markdown]
# **HEAD OF DATA**

# %%
df.head()
# Out:
#      Book Id                                              Title  \
# 0   50617439                                    Louvor da Terra
# 1   11838916  Cat Stories (Everyman's Library Pocket Classic...
# 2   37844623                      The Blood (Jem Flockhart, #3)
# 3  124798505                              Four Seasons in Japan
# 4   24945319  Gone with the Gin: Cocktails with a Hollywood ...
#
#                  Author             Author l-f     Additional Authors  \
# 0        Byung-Chul Han        Han, Byung-Chul  Miguel Serras Pereira
# 1  Diana Secker Tesdell  Tesdell, Diana Secker                    NaN
# 2          E.S. Thomson          Thomson, E.S.                    NaN
# 3         Nick  Bradley          Bradley, Nick                    NaN
# 4           Tim Federle           Federle, Tim                    NaN
#
#          ISBN        ISBN13  My Rating  Average Rating  \
# 0  9896419884  9.789900e+12          0            3.76
# 1   307700895  9.780310e+12          0            3.56
# 2  1472126572  9.781470e+12          5            4.08
# 3  085752934X  9.780860e+12          0            4.26
# 4   762458607  9.780760e+12          3            4.15
#
#                  Publisher  ...   Date Read  Date Added  \
# 0  Relógio D'Água Editores  ...         NaN  30/01/2024
# 1       Everyman's Library  ...         NaN  29/01/2024
# 2                Constable  ...  28/01/2024  18/01/2024
# 3                Doubleday  ...         NaN  08/12/2023
# 4      Running Press Adult  ...  31/08/2020  31/08/2020
#
#                                        Bookshelves  \
# 0                                          to-read
# 1  cats, fiction, short-stories, currently-reading
# 2                      historical-fiction, mystery
# 3                                          to-read
# 4                            cookbook, non-fiction
#
#                           Bookshelves with positions    Exclusive Shelf  \
# 0                                     to-read (#179)            to-read
# 1  cats (#5), fiction (#35), short-stories (#2), ...  currently-reading
# 2              historical-fiction (#5), mystery (#7)               read
# 3                                     to-read (#178)            to-read
# 4                   cookbook (#3), non-fiction (#19)               read
#
#   My Review Spoiler Private Notes Read Count Owned Copies
# 0       NaN     NaN           NaN          0            0
# 1       NaN     NaN           NaN          1            0
# 2       NaN     NaN           NaN          1            0
# 3       NaN     NaN           NaN          0            0
# 4       NaN     NaN           NaN          1            1
#
# [5 rows x 24 columns]

# %% [markdown]
# **SHAPE OF DATA**

# %%
df.shape
# Out:
# (406, 24)

# %% [markdown]
# **INFORMATION OF DATA**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Book Id                     406 non-null    int64
#  1   Title                       406 non-null    object
#  2   Author                      406 non-null    object
#  3   Author l-f                  406 non-null    object
#  4   Additional Authors          114 non-null    object
#  5   ISBN                        317 non-null    object
#  6   ISBN13                      324 non-null    float64
#  7   My Rating                   406 non-null    int64
#  8   Average Rating              406 non-null    float64
#  9   Publisher                   394 non-null    object
#  10  Binding                     400 non-null    object
#  11  Number of Pages             395 non-null    float64
#  12  Year Published              399 non-null    float64
#  13  Original Publication Year   370 non-null    float64
#  14  Date Read                   127 non-null    object
#  15  Date Added                  406 non-null    object
#  16  Bookshelves                 395 non-null    object
#  17  Bookshelves with positions  395 non-null    object
#  18  Exclusive Shelf             406 non-null    object
#  19  My Review                   17 non-null     object
#  20  Spoiler                     3 non-null      object
#  21  Private Notes               17 non-null     object
#  22  Read Count                  406 non-null    int64
#  23  Owned Copies                406 non-null    int64
# dtypes: float64(5), int64(4), object(15)
# memory usage: 76.3+ KB

# %% [markdown]
# **DESCRIBE**

# %%
df.describe()
# Out:
#             Book Id        ISBN13   My Rating  Average Rating  \
# count  4.060000e+02  3.240000e+02  406.000000      406.000000
# mean   2.481609e+07  9.782653e+12    2.100985        4.057291
# std    2.487910e+07  3.321125e+09    2.257968        0.474023
# min    1.000000e+00  9.780010e+12    0.000000        0.000000
# 25%    1.063908e+06  9.780740e+12    0.000000        3.842500
# 50%    2.079318e+07  9.781590e+12    0.000000        4.110000
# 75%    4.198341e+07  9.781910e+12    5.000000        4.300000
# max    2.023415e+08  9.798660e+12    5.000000        5.000000
#
#        Number of Pages  Year Published  Original Publication Year  Read Count  \
# count       395.000000      399.000000                 370.000000  406.000000
# mean        312.934177     2010.573935                1986.335135    0.509852
# std         194.046637       11.148785                  78.314051    0.515107
# min           0.000000     1925.000000                1400.000000    0.000000
# 25%         192.000000     2005.000000                1994.000000    0.000000
# 50%         273.000000     2013.000000                2007.000000    1.000000
# 75%         392.500000     2019.000000                2017.000000    1.000000
# max        1234.000000     2024.000000                2024.000000    2.000000
#
#        Owned Copies
# count    406.000000
# mean       0.128079
# std        0.334590
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# **DUPLICATE CHECKING**

# %%
dups=df.duplicated()
print('Number of duplicates:%d'% (dups.sum()))
df[dups]
# Out:
# Number of duplicates:20
#        Book Id                                              Title  \
# 72      248867                                   Berserk, Vol. 14
# 90    50617439                                    Louvor da Terra
# 91      248871                      Berserk, Vol. 1 (Berserk, #1)
# 195    2511233                               The Company of Swans
# 227   36477428              魔法使いの嫁 9 特装版 (Mahōtsukai no yome, #9)
# 255   53671481  Magia: Rituais, poções e feitiços para descobr...
# 263   12995005                Coroa de Erva (Masters of Rome, #2)
# 278      12006                                           Dead Air
# 280   10365636                      The Horrid Glory of Its Wings
# 284  124798505                              Four Seasons in Japan
# 307      24929                                               Lost
# 311       7604                                             Lolita
# 328     348573                  The Borrowers (The Borrowers, #1)
# 393       6185                                  Wuthering Heights
# 396       4671                                   The Great Gatsby
# 399      11588                      The Shining (The Shining, #1)
# 400    6196797  The Hammer of Witches: A Complete Translation ...
# 402   38591165                                   The Doll Factory
# 404      43820                             The Witches' Companion
# 405   50781007  Chinese Fairy Tales and Legends: A Gift Editio...
#
#                    Author             Author l-f  \
# 72          Kentaro Miura         Miura, Kentaro
# 90         Byung-Chul Han        Han, Byung-Chul
# 91          Kentaro Miura         Miura, Kentaro
# 195           Jim Crumley           Crumley, Jim
# 227         Kore Yamazaki         Yamazaki, Kore
# 255        Sarah Bartlett        Bartlett, Sarah
# 263    Colleen McCullough    McCullough, Colleen
# 278            Iain Banks            Banks, Iain
# 280        Elizabeth Bear        Bear, Elizabeth
# 284         Nick  Bradley          Bradley, Nick
# 307       Gregory Maguire       Maguire, Gregory
# 311      Vladimir Nabokov      Nabokov, Vladimir
# 328           Mary Norton           Norton, Mary
# 393          Emily Brontë          Brontë, Emily
# 396   F. Scott Fitzgerald   Fitzgerald, F. Scott
# 399          Stephen King          King, Stephen
# 400       Heinrich Kramer       Kramer, Heinrich
# 402     Elizabeth Macneal     Macneal, Elizabeth
# 404    Katherine Ramsland    Ramsland, Katherine
# 405  Frederick H. Martens  Martens, Frederick H.
#
#                                     Additional Authors        ISBN  \
# 72                                                 NaN  1593075014
# 90                               Miguel Serras Pereira  9896419884
# 91                                                 NaN  1593070209
# 195                                     Harry Brockway  1860465587
# 227                                             ヤマザキコレ  4800007275
# 255                                                NaN         NaN
# 263                                                NaN  9722902229
# 278                                                NaN   349116644
# 280                                                NaN  1429926007
# 284                                                NaN  085752934X
# 307                                      Douglas Smith    60988649
# 311                                        Craig Raine         NaN
# 328  Diana Stanley, Beth Krush, Joe Krush, Leonard ...   152047379
# 393  Richard J. Dunn, Charlotte Brontë, John Bugg, ...         NaN
# 396                                                NaN         NaN
# 399                                                NaN   450040186
# 400             Heinrich Kramer, Christopher S. Mackay   521747872
# 402                                                NaN  1529002397
# 404                                          Anne Rice   345406249
# 405                                    Richard Wilhelm  1912392143
#
#            ISBN13  My Rating  Average Rating  \
# 72   9.781590e+12          5            4.57
# 90   9.789900e+12          0            3.76
# 91   9.781590e+12          5            4.48
# 195  9.781860e+12          0            4.29
# 227  9.784800e+12          5            4.35
# 255  9.789900e+12          4            3.58
# 263  9.789720e+12          4            4.33
# 278  9.780350e+12          2            3.55
# 280  9.781430e+12          0            3.69
# 284  9.780860e+12          0            4.26
# 307  9.780060e+12          0            2.83
# 311           NaN          3            3.88
# 328  9.780150e+12          0            4.03
# 393           NaN          0            3.89
# 396           NaN          4            3.93
# 399  9.780450e+12          0            4.27
# 400  9.780520e+12          2            3.19
# 402  9.781530e+12          5            3.78
# 404  9.780350e+12          0            4.17
# 405  9.781910e+12          0            3.47
#
#                                      Publisher  ...   Date Read  Date Added  \
# 72                            Dark Horse Manga  ...  12/04/2023  23/04/2023
# 90                     Relógio D'Água Editores  ...         NaN  30/01/2024
# 91                            Dark Horse Manga  ...  02/03/2023  20/03/2023
# 195                                 Harvill Pr  ...         NaN  18/01/2023
# 227                                    マッグガーデン  ...  16/04/2022  02/06/2022
# 255                                 Pergaminho  ...  20/07/2020  16/07/2020
# 263                                      Difel  ...         NaN  27/10/2021
# 278                                     Abacus  ...  03/01/2022  29/11/2020
# 280                                  Tor Books  ...         NaN  02/12/2020
# 284                                  Doubleday  ...         NaN  08/12/2023
# 307                  William Morrow Paperbacks  ...         NaN  12/08/2020
# 311                                    Penguin  ...  28/05/2021  25/10/2020
# 328                              Clarion Books  ...         NaN  02/12/2020
# 393                                     Norton  ...         NaN  20/09/2020
# 396                                   Scribner  ...         NaN  09/02/2020
# 399  New English Library (Hodder & Stoughton)   ...         NaN  04/08/2020
# 400                 Cambridge University Press  ...  26/02/2020  26/02/2020
# 402                                    Picador  ...         NaN  21/07/2019
# 404                           Ballantine Books  ...         NaN  16/01/2022
# 405                           Bloomsbury China  ...         NaN  18/01/2023
#
#                                  Bookshelves  \
# 72   fantasy, horror-thriller, manga, gothic
# 90                                   to-read
# 91   horror-thriller, manga, fantasy, gothic
# 195                                  to-read
# 227                           fantasy, manga
# 255                                   occult
# 263    historical-fiction, currently-reading
# 278                                  fiction
# 280                                  to-read
# 284                                  to-read
# 307                                  to-read
# 311                                  fiction
# 328                                  to-read
# 393                                  to-read
# 396                                  fiction
# 399                                  to-read
# 400                              non-fiction
# 402                                  fiction
# 404                                  to-read
# 405                                  to-read
#
#                             Bookshelves with positions    Exclusive Shelf  \
# 72   fantasy (#78), horror-thriller (#20), manga (#...               read
# 90                                      to-read (#179)            to-read
# 91   horror-thriller (#9), manga (#17), fantasy (#9...               read
# 195                                     to-read (#144)            to-read
# 227                          fantasy (#60), manga (#8)               read
# 255                                        occult (#7)               read
# 263    historical-fiction (#3), currently-reading (#5)  currently-reading
# 278                                      fiction (#22)               read
# 280                                      to-read (#48)            to-read
# 284                                     to-read (#178)            to-read
# 307                                      to-read (#27)            to-read
# 311                                      fiction (#20)               read
# 328                                      to-read (#50)            to-read
# 393                                      to-read (#29)            to-read
# 396                                       fiction (#3)               read
# 399                                      to-read (#16)            to-read
# 400                                   non-fiction (#1)               read
# 402                                       fiction (#5)               read
# 404                                      to-read (#62)            to-read
# 405                                     to-read (#132)            to-read
#
#     My Review Spoiler    Private Notes Read Count Owned Copies
# 72        NaN     NaN              NaN          1            0
# 90        NaN     NaN              NaN          0            0
# 91        NaN     NaN              NaN          1            0
# 195       NaN     NaN              NaN          0            0
# 227       NaN     NaN              NaN          1            0
# 255       NaN     NaN    gift from Mum          1            1
# 263       NaN     NaN  belonged to dad          1            1
# 278       NaN     NaN              NaN          1            0
# 280       NaN     NaN              NaN          0            0
# 284       NaN     NaN              NaN          0            0
# 307       NaN     NaN              NaN          0            0
# 311       NaN     NaN              NaN          1            0
# 328       NaN     NaN              NaN          0            0
# 393       NaN     NaN              NaN          0            0
# 396       NaN     NaN              NaN          1            0
# 399       NaN     NaN              NaN          0            0
# 400       NaN     NaN              NaN          1            0
# 402       NaN     NaN              NaN          1            0
# 404       NaN     NaN              NaN          0            0
# 405       NaN     NaN              NaN          0            1
#
# [20 rows x 24 columns]

# %% [markdown]
# **REMOVING DUPLICATES**

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# **RECHECKING DUPLICATES**

# %%
dups=df.duplicated()
print('Number of duplicates:%d'% (dups.sum()))
df[dups]
# Out:
# Number of duplicates:0
# Empty DataFrame
# Columns: [Book Id, Title, Author, Author l-f, Additional Authors, ISBN, ISBN13, My Rating, Average Rating, Publisher, Binding, Number of Pages, Year Published, Original Publication Year, Date Read, Date Added, Bookshelves, Bookshelves with positions, Exclusive Shelf, My Review, Spoiler, Private Notes, Read Count, Owned Copies]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.shape
# Out:
# (386, 24)

# %% [markdown]
# **CHECK FOR OUTLINER**

# %%
df.boxplot(column='Book Id')
plt.show()

# %%
df.boxplot(column='ISBN13')
plt.show()

# %%
df.boxplot(column='My Rating')
plt.show()

# %%
df.boxplot(column='Average Rating')
plt.show()

# %%
df.boxplot(column='Number of Pages')
plt.show()

# %%
df.boxplot(column='Year Published')
plt.show()

# %%
df.boxplot(column='Original Publication Year')
plt.show()

# %%
df.boxplot(column='Read Count')
plt.show()

# %%
df.boxplot(column='Owned Copies')
plt.show()

# %% [markdown]
# **TREATING OUTLINERS**

# %%
def remove_outliner(col):
  sorted(col)
  Q1,Q3=col.quantile([0.25,0.75])
  IQR=Q3-Q1
  lower_range=Q1-(1.5*IQR)
  upper_range=Q3+(1.5*IQR)
  return lower_range,upper_range

# %%
lrbook_Id,urbook_Id=remove_outliner(df['Book Id'])
df['Book Id']=np.where(df['Book Id']<lrbook_Id,lrbook_Id,df['Book Id'])
df['Book Id']=np.where(df['Book Id']>urbook_Id,urbook_Id,df['Book Id'])

lrISBN13,urISBN13=remove_outliner(df['ISBN13'])
df['ISBN13']=np.where(df['ISBN13']<lrISBN13,lrISBN13,df['ISBN13'])
df['ISBN13']=np.where(df['ISBN13']>urISBN13,urISBN13,df['ISBN13'])

lrMy_Rating,urMy_Rating=remove_outliner(df['My Rating'])
df['My Rating']=np.where(df['My Rating']<lrMy_Rating,lrMy_Rating,df['My Rating'])
df['My Rating']=np.where(df['My Rating']>urMy_Rating,urMy_Rating,df['My Rating'])

lrAverage_Rating,urAverage_Rating=remove_outliner(df['Average Rating'])
df['Average Rating']=np.where(df['Average Rating']<lrAverage_Rating,lrAverage_Rating,df['Average Rating'])
df['Average Rating']=np.where(df['Average Rating']>urAverage_Rating,urAverage_Rating,df['Average Rating'])

lrNumber_of_Pages,urNumber_of_Pages=remove_outliner(df['Number of Pages'])
df['Number of Pages']=np.where(df['Number of Pages']<lrNumber_of_Pages,lrNumber_of_Pages,df['Number of Pages'])
df['Number of Pages']=np.where(df['Number of Pages']>urNumber_of_Pages,urNumber_of_Pages,df['Number of Pages'])

lrYear_Published,urYear_Published=remove_outliner(df['Year Published'])
df['Year Published']=np.where(df['Year Published']<lrYear_Published,lrYear_Published,df['Year Published'])
df['Year Published']=np.where(df['Year Published']>urYear_Published,urYear_Published,df['Year Published'])

lrOriginal_Publication_Year,urOriginal_Publication_Year=remove_outliner(df['Original Publication Year'])
df['Original Publication Year']=np.where(df['Original Publication Year']<lrOriginal_Publication_Year,lrOriginal_Publication_Year,df['Original Publication Year'])
df['Original Publication Year']=np.where(df['Original Publication Year']>urOriginal_Publication_Year,urOriginal_Publication_Year,df['Original Publication Year'])

lrRead_Count,urRead_Count=remove_outliner(df['Read Count'])
df['Read Count']=np.where(df['Read Count']<lrRead_Count,lrRead_Count,df['Read Count'])
df['Read Count']=np.where(df['Read Count']>urRead_Count,urRead_Count,df['Read Count'])

lrOwned_Copies,urOwned_Copies=remove_outliner(df['Owned Copies'])
df['Owned Copies']=np.where(df['Owned Copies']<lrOwned_Copies,lrOwned_Copies,df['Owned Copies'])
df['Owned Copies']=np.where(df['Owned Copies']>urOwned_Copies,urOwned_Copies,df['Owned Copies'])
df.shape
# Out:
# (386, 24)

# %% [markdown]
# **RECHECKING OUTLINER**

# %%
df.boxplot(column='Book Id')
plt.show()

# %%
df.boxplot(column='ISBN13')
plt.show()

# %%
df.boxplot(column='My Rating')
plt.show()

# %%
df.boxplot(column='Average Rating')
plt.show()

# %%
df.boxplot(column='Number of Pages')
plt.show()

# %%
df.boxplot(column='Year Published')
plt.show()

# %%
df.boxplot(column='Original Publication Year')
plt.show()

# %%
df.boxplot(column='Read Count')
plt.show()

# %%
df.boxplot(column='Owned Copies')
plt.show()

# %% [markdown]
# **CHECKING MISSING VALUE**

# %%
df.isnull().sum()
# Out:
# Book Id                         0
# Title                           0
# Author                          0
# Author l-f                      0
# Additional Authors            282
# ISBN                           85
# ISBN13                         79
# My Rating                       0
# Average Rating                  0
# Publisher                      12
# Binding                         6
# Number of Pages                11
# Year Published                  7
# Original Publication Year      35
# Date Read                     266
# Date Added                      0
# Bookshelves                    11
# Bookshelves with positions     11
# Exclusive Shelf                 0
# My Review                     369
# Spoiler                       383
# Private Notes                 371
# Read Count                      0
# Owned Copies                    0
# dtype: int64

# %% [markdown]
# **Replacing With Median Value**

# %%
df[df.isnull().sum()[df.isnull().sum()>0].index].dtypes
# Out:
# Additional Authors             object
# ISBN                           object
# ISBN13                        float64
# Publisher                      object
# Binding                        object
# Number of Pages               float64
# Year Published                float64
# Original Publication Year     float64
# Date Read                      object
# Bookshelves                    object
# Bookshelves with positions     object
# My Review                      object
# Spoiler                        object
# Private Notes                  object
# dtype: object

# %% [markdown]
# **REPLACING NUMERICAL VALUE USING MEDIAN**

# %%
median1=df["ISBN13"].median()
median2=df["Number of Pages"].median()
median3=df["Year Published"].median()
median4=df["Original Publication Year"].median()

df["ISBN13"].replace(np.nan,median1,inplace=True)
df["Number of Pages"].replace(np.nan,median2,inplace=True)
df["Year Published"].replace(np.nan,median3,inplace=True)
df["Original Publication Year"].replace(np.nan,median4,inplace=True)
# Out:
# /tmp/ipython-input-3279981811.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ISBN13"].replace(np.nan,median1,inplace=True)
# /tmp/ipython-input-3279981811.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Number of Pages"].replace(np.nan,median2,inplace=True)
# /tmp/ipython-input-3279981811.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Year Published"].replace(np.nan,median3,inplace=True)
# /tmp/ipython-input-3279981811.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Original Publication Year"].replace(np.nan,median4,inplace=True)

# %%
mode1=df["Additional Authors"].mode().values[0]
mode2=df["ISBN"].mode().values[0]
mode3=df["Publisher"].mode().values[0]
mode4=df["Binding"].mode().values[0]
mode5=df["Date Read"].mode().values[0]
mode6=df["Bookshelves"].mode().values[0]
mode7=df["Bookshelves with positions"].mode().values[0]
mode8=df["My Review"].mode().values[0]
mode9=df["Spoiler"].mode().values[0]
mode10=df["Private Notes"].mode().values[0]

df["Additional Authors"].replace(np.nan,mode1,inplace=True)
df["ISBN"].replace(np.nan,mode2,inplace=True)
df["Publisher"].replace(np.nan,mode3,inplace=True)
df["Binding"].replace(np.nan,mode4,inplace=True)
df["Date Read"].replace(np.nan,mode5,inplace=True)
df["Bookshelves"].replace(np.nan,mode6,inplace=True)
df["Bookshelves with positions"].replace(np.nan,mode7,inplace=True)
df["My Review"].replace(np.nan,mode8,inplace=True)
df["Spoiler"].replace(np.nan,mode9,inplace=True)
df["Private Notes"].replace(np.nan,mode10,inplace=True)
# Out:
# /tmp/ipython-input-447795831.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Additional Authors"].replace(np.nan,mode1,inplace=True)
# /tmp/ipython-input-447795831.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ISBN"].replace(np.nan,mode2,inplace=True)
# /tmp/ipython-input-447795831.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Publisher"].replace(np.nan,mode3,inplace=True)
# /tmp/ipython-input-447795831.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Binding"].replace(np.nan,mode4,inplace=True)
# /tmp/ipython-input-447795831.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Date Read"].replace(np.nan,mode5,inplace=True)
# /tmp/ipython-input-447795831.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Bookshelves"].replace(np.nan,mode6,inplace=True)
# /tmp/ipython-input-447795831.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Bookshelves with positions"].replace(np.nan,mode7,inplace=True)
# /tmp/ipython-input-447795831.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["My Review"].replace(np.nan,mode8,inplace=True)
# /tmp/ipython-input-447795831.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Spoiler"].replace(np.nan,mode9,inplace=True)
# /tmp/ipython-input-447795831.py:20: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Spoiler"].replace(np.nan,mode9,inplace=True)
# /tmp/ipython-input-447795831.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Private Notes"].replace(np.nan,mode10,inplace=True)

# %% [markdown]
# **RECHECKING MISSING VALUES**

# %%
df.isnull().sum()
# Out:
# Book Id                       0
# Title                         0
# Author                        0
# Author l-f                    0
# Additional Authors            0
# ISBN                          0
# ISBN13                        0
# My Rating                     0
# Average Rating                0
# Publisher                     0
# Binding                       0
# Number of Pages               0
# Year Published                0
# Original Publication Year     0
# Date Read                     0
# Date Added                    0
# Bookshelves                   0
# Bookshelves with positions    0
# Exclusive Shelf               0
# My Review                     0
# Spoiler                       0
# Private Notes                 0
# Read Count                    0
# Owned Copies                  0
# dtype: int64

# %% [markdown]
# **UNIVARIATE ANALLYSIS**

# %%
sns.histplot(df.ISBN13,kde=True)
# Out:
# <Axes: xlabel='ISBN13', ylabel='Count'>

# %%
sns.histplot(df["My Rating"],kde=True)
# Out:
# <Axes: xlabel='My Rating', ylabel='Count'>

# %%
sns.histplot(df["Average Rating"],kde=True)
# Out:
# <Axes: xlabel='Average Rating', ylabel='Count'>

# %%
sns.histplot(df["Number of Pages"],kde=True)
# Out:
# <Axes: xlabel='Number of Pages', ylabel='Count'>

# %%
sns.histplot(df["Year Published"],kde=True)
# Out:
# <Axes: xlabel='Year Published', ylabel='Count'>

# %%
sns.histplot(df["Original Publication Year"],kde=True)
# Out:
# <Axes: xlabel='Original Publication Year', ylabel='Count'>

# %%
sns.histplot(df["Date Read"],kde=True)
# Out:
# <Axes: xlabel='Date Read', ylabel='Count'>

# %%
sns.histplot(df["Date Added"],kde=True)
# Out:
# <Axes: xlabel='Date Added', ylabel='Count'>

# %%
sns.histplot(df["Read Count"],kde=True)
# Out:
# <Axes: xlabel='Read Count', ylabel='Count'>

# %%
sns.histplot(df["Owned Copies"],kde=True)
# Out:
# <Axes: xlabel='Owned Copies', ylabel='Count'>

# %% [markdown]
# **BIVARIATE ANALYSIS**

# %%
sns.pairplot(df)
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                             Book Id    ISBN13  My Rating  Average Rating  \
# Book Id                    1.000000  0.184387  -0.201256       -0.130437
# ISBN13                     0.184387  1.000000   0.257984        0.075329
# My Rating                 -0.201256  0.257984   1.000000        0.388858
# Average Rating            -0.130437  0.075329   0.388858        1.000000
# Number of Pages           -0.141355 -0.143763  -0.059604       -0.030641
# Year Published             0.780459  0.162359  -0.159729        0.004420
# Original Publication Year  0.519551  0.060735  -0.142121        0.026429
# Spoiler                         NaN       NaN        NaN             NaN
# Read Count                -0.161608  0.231953   0.821459        0.290729
# Owned Copies                    NaN       NaN        NaN             NaN
#
#                            Number of Pages  Year Published  \
# Book Id                          -0.141355        0.780459
# ISBN13                           -0.143763        0.162359
# My Rating                        -0.059604       -0.159729
# Average Rating                   -0.030641        0.004420
# Number of Pages                   1.000000       -0.102984
# Year Published                   -0.102984        1.000000
# Original Publication Year        -0.043362        0.611268
# Spoiler                                NaN             NaN
# Read Count                        0.032365       -0.124402
# Owned Copies                           NaN             NaN
#
#                            Original Publication Year  Spoiler  Read Count  \
# Book Id                                     0.519551      NaN   -0.161608
# ISBN13                                      0.060735      NaN    0.231953
# My Rating                                  -0.142121      NaN    0.821459
# Average Rating                              0.026429      NaN    0.290729
# Number of Pages                            -0.043362      NaN    0.032365
# Year Published                              0.611268      NaN   -0.124402
# Original Publication Year                   1.000000      NaN   -0.182614
# Spoiler                                          NaN      NaN         NaN
# Read Count                                 -0.182614      NaN    1.000000
# Owned Copies                                     NaN      NaN         NaN
#
#                            Owned Copies
# Book Id                             NaN
# ISBN13                              NaN
# My Rating                           NaN
# Average Rating                      NaN
# Number of Pages                     NaN
# Year Published                      NaN
# Original Publication Year           NaN
# Spoiler                             NaN
# Read Count                          NaN
# Owned Copies                        NaN

# %% [markdown]
# **CORRELATION HEATMAP**

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(numeric_only=True),annot=True,fmt='.2f', cmap='Greens')
plt.show()

# %% [markdown]
# **NORMALIZATION AND STANDARDIZATION**

# %%
from sklearn.preprocessing import StandardScaler
std_scale=StandardScaler()
std_scale
# Out:
# StandardScaler()

# %%
cols_to_scale = ["My Rating","Average Rating","Number of Pages","Year Published","Original Publication Year","Read Count","Owned Copies"]
for col in cols_to_scale:
    df[col] = std_scale.fit_transform(df[[col]])

# %%
df.head()
# Out:
#     Book Id                                              Title  \
# 0  1.038349                                    Louvor da Terra
# 1 -0.522253  Cat Stories (Everyman's Library Pocket Classic...
# 2  0.524320                      The Blood (Jem Flockhart, #3)
# 3  4.023690                              Four Seasons in Japan
# 4  0.005201  Gone with the Gin: Cocktails with a Hollywood ...
#
#                  Author             Author l-f     Additional Authors  \
# 0        Byung-Chul Han        Han, Byung-Chul  Miguel Serras Pereira
# 1  Diana Secker Tesdell  Tesdell, Diana Secker                    NaN
# 2          E.S. Thomson          Thomson, E.S.                    NaN
# 3         Nick  Bradley          Bradley, Nick                    NaN
# 4           Tim Federle           Federle, Tim                    NaN
#
#          ISBN        ISBN13  My Rating  Average Rating  \
# 0  9896419884  9.789900e+12  -0.931624       -0.627939
# 1   307700895  9.780310e+12  -0.931624       -1.050380
# 2  1472126572  9.781470e+12   1.285488        0.047967
# 3  085752934X  9.780860e+12  -0.931624        0.428164
# 4   762458607  9.780760e+12   0.398643        0.195821
#
#                  Publisher  ...   Date Read  Date Added  \
# 0  Relógio D'Água Editores  ...         NaN  30/01/2024
# 1       Everyman's Library  ...         NaN  29/01/2024
# 2                Constable  ...  28/01/2024  18/01/2024
# 3                Doubleday  ...         NaN  08/12/2023
# 4      Running Press Adult  ...  31/08/2020  31/08/2020
#
#                                        Bookshelves  \
# 0                                          to-read
# 1  cats, fiction, short-stories, currently-reading
# 2                      historical-fiction, mystery
# 3                                          to-read
# 4                            cookbook, non-fiction
#
#                           Bookshelves with positions    Exclusive Shelf  \
# 0                                     to-read (#179)            to-read
# 1  cats (#5), fiction (#35), short-stories (#2), ...  currently-reading
# 2              historical-fiction (#5), mystery (#7)               read
# 3                                     to-read (#178)            to-read
# 4                   cookbook (#3), non-fiction (#19)               read
#
#   My Review Spoiler Private Notes Read Count Owned Copies
# 0       NaN     NaN           NaN  -0.991021    -0.383266
# 1       NaN     NaN           NaN   0.952720    -0.383266
# 2       NaN     NaN           NaN   0.952720    -0.383266
# 3       NaN     NaN           NaN  -0.991021    -0.383266
# 4       NaN     NaN           NaN   0.952720     2.609155
#
# [5 rows x 24 columns]

# %% [markdown]
# **ENCODING**

# %%
columns=["Title", "Author", "Author l-f", "Additional Authors", "ISBN","Publisher", "Binding", "Date Read", "Date Added", "Bookshelves",
"Bookshelves with positions", "Exclusive Shelf", "My Review","Spoiler", "Private Notes"]
dummies=pd.get_dummies(df[columns], drop_first=True)
df=pd.concat([df, dummies], axis=1)
df.drop(columns, axis=1, inplace=True)

# %%
df.head()
# Out:
#     Book Id        ISBN13  My Rating  Average Rating  Number of Pages  \
# 0  1.038349  9.789900e+12  -0.931624       -0.627939        -0.830410
# 1 -0.522253  9.780310e+12  -0.931624       -1.050380         0.449254
# 2  0.524320  9.781470e+12   1.285488        0.047967         0.320256
# 3  4.023690  9.780860e+12  -0.931624        0.428164         0.119018
# 4  0.005201  9.780760e+12   0.398643        0.195821        -0.830410
#
#    Year Published  Original Publication Year  Read Count  Owned Copies  \
# 0        0.846541                   0.238656   -0.991021     -0.383266
# 1        0.038264                   0.315375    0.952720     -0.383266
# 2        0.666924                   0.404879    0.952720     -0.383266
# 3        1.115966                   0.468811   -0.991021     -0.383266
# 4        0.397498                   0.366520    0.952720      2.609155
#
#    Title_"Reader's Digest" Farmhouse Cookery: Recipes from the Country Kitchen  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    ...  My Review_Mind-blown in space  Private Notes_belonged to Grandpa  \
# 0  ...                          False                              False
# 1  ...                          False                              False
# 2  ...                          False                              False
# 3  ...                          False                              False
# 4  ...                          False                              False
#
#    Private Notes_belonged to dad  Private Notes_gift from Hufflepuff  \
# 0                          False                               False
# 1                          False                               False
# 2                          False                               False
# 3                          False                               False
# 4                          False                               False
#
#    Private Notes_gift from Meike  Private Notes_gift from Mum  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# 3                          False                        False
# 4                          False                        False
#
#    Private Notes_lent by Gamu, Jim's wife  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Private Notes_read together with Meike  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    Private Notes_started borrowing it from RCN's library. Finishing as ebook.  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Private Notes_tried to read together with Meike xD
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
# [5 rows x 2130 columns]
